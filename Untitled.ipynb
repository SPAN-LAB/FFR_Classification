# %%
def if_power_of_two(x):
    if 0 < x <= 2:
        return True
    while x > 2:
        x = x/2
        if x == 2:
            return True
    return False

# %%
if_power_of_two(1)
# Out:
# True
